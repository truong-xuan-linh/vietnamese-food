# %% [markdown]
# # **Kết nối với Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # **Clone github repo đồ án**

# %%
# !git clone https://github.com/VinhPhamBG/VietnameseFood.git
# Out:
# Cloning into 'VietnameseFood'...
# remote: Enumerating objects: 697, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 697 (delta 0), reused 3 (delta 0), pack-reused 693
# Receiving objects: 100% (697/697), 199.96 MiB | 19.41 MiB/s, done.
# Resolving deltas: 100% (384/384), done.
# Checking out files: 100% (53/53), done.

# %% [markdown]
# # **Download dataset về Drive**

# %%
# !gdown https://drive.google.com/uc?id=1jQP4MqI-jS6tSJq9a-DOOfK2EJAsObyu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jQP4MqI-jS6tSJq9a-DOOfK2EJAsObyu
# To: /content/drive/MyDrive/data_split.zip
# 5.65GB [01:55, 49.1MB/s]

# %%
# !unzip data_split.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: data_split/data_train/com_chay/com_chay_760.jpg
#   inflating: data_split/data_train/com_chay/com_chay_761.jpg
#   inflating: data_split/data_train/com_chay/com_chay_762.jpg
#   inflating: data_split/data_train/com_chay/com_chay_763.jpg
#   inflating: data_split/data_train/com_chay/com_chay_764.jpg
#   inflating: data_split/data_train/com_chay/com_chay_765.jpg
#   inflating: data_split/data_train/com_chay/com_chay_766.jpg
#   inflating: data_split/data_train/com_chay/com_chay_767.jpg
#   inflating: data_split/data_train/com_chay/com_chay_768.jpg
#   inflating: data_split/data_train/com_chay/com_chay_769.jpg
#   inflating: data_split/data_train/com_chay/com_chay_770.jpg
#   inflating: data_split/data_train/com_chay/com_chay_771.jpg
#   inflating: data_split/data_train/com_chay/com_chay_772.jpg
#   inflating: data_split/data_train/com_chay/com_chay_773.jpg
# ...
